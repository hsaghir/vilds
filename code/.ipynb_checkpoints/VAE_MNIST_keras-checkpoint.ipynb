# %% [markdown]
# # import stuff and set random seeds

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import objectives
from keras.datasets import mnist
from keras import backend as K

# %% [markdown]
# # encoder/decode network size

# %%
batch_size=100
digit_size=28
original_dim=784
intermediate_dim=256
latent_dim=2

nb_epochs=50
epsilon_std=1.0

# %% [markdown]
# # encoder

# %%
X=Input(batch_shape=(batch_size,original_dim))
h=Dense(intermediate_dim, activation='relu')(X)
z_mean=Dense(latent_dim)(h)
z_log_var=Dense(latent_dim)(h)

# %% [markdown]
# # sampling from latent for decoder

# %%
def sampling(args):
    z_mean,z_log_var=args
    epsilon=K.random_normal(shape=(batch_size, latent_dim), mean=0., std=epsilon_std)
    return z_mean+K.exp(z_log_var/2)*epsilon

# a keras lambda layer computes arbitrary function on the output of a layer
# so z is effectively combining mean and variance layers through sampling func 
z= Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# %% [markdown]
# # decoder

# %%
h_decoder=Dense(intermediate_dim, activation='relu')
X_bar=Dense(original_dim,activation='sigmoid')

# we instantiate these layers separately so as to reuse them later
h_decoded = h_decoder(z)
X_decoded = X_bar(h_decoded)

# %% [markdown]
# # VAE loss

# %%
def vae_loss(x,x_bar):
    reconst_loss=original_dim*objectives.binary_crossentropy(x, x_bar)
    kl_loss=-0.5*K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return reconst_loss + kl_loss

# %% [markdown]
# # compile model and ready data for training

# %%
# build and compile model
vae=Model(X , X_decoded)
vae.compile(optimizer='adam', loss=vae_loss)

# load MNIST data for training
(x_train, y_train),(x_test, y_test)=mnist.load_data()

# normalize input and make them float32 to run on GPU
x_train=x_train.astype('float32')/ 255.
x_test=x_test.astype('float32')/255.

# convert 28x28 images into 784-vectors
x_train=x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test=x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %% [markdown]
# # train model based on the loss func we defined

# %%
# x_train is required for input and loss output as target
vae.fit(x_train,x_train, shuffle=True, nb_epoch=nb_epochs, batch_size=batch_size, validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 0s - loss: 189.0302 - val_loss: 177.1629
# Epoch 2/50
# 60000/60000 [==============================] - 0s - loss: 175.1459 - val_loss: 173.1722
# Epoch 3/50
# 60000/60000 [==============================] - 0s - loss: 172.7574 - val_loss: 171.6295
# Epoch 4/50
# 60000/60000 [==============================] - 0s - loss: 171.6094 - val_loss: 170.7398
# Epoch 5/50
# 60000/60000 [==============================] - 0s - loss: 170.8297 - val_loss: 170.0949
# Epoch 6/50
# 60000/60000 [==============================] - 0s - loss: 170.1870 - val_loss: 169.6079
# Epoch 7/50
# 60000/60000 [==============================] - 0s - loss: 169.6397 - val_loss: 169.1195
# Epoch 8/50
# 60000/60000 [==============================] - 0s - loss: 169.1793 - val_loss: 168.7444
# Epoch 9/50
# 60000/60000 [==============================] - 0s - loss: 168.7510 - val_loss: 168.4639
# Epoch 10/50
# 60000/60000 [==============================] - 0s - loss: 168.3452 - val_loss: 167.9410
# Epoch 11/50
# 60000/60000 [==============================] - 0s - loss: 167.9729 - val_loss: 167.5927
# Epoch 12/50
# 60000/60000 [==============================] - 0s - loss: 167.6012 - val_loss: 167.3563
# Epoch 13/50
# 60000/60000 [==============================] - 0s - loss: 167.2622 - val_loss: 167.0177
# Epoch 14/50
# 60000/60000 [==============================] - 0s - loss: 166.9362 - val_loss: 166.6289
# Epoch 15/50
# 60000/60000 [==============================] - 0s - loss: 166.5952 - val_loss: 166.3495
# Epoch 16/50
# 60000/60000 [==============================] - 0s - loss: 166.2695 - val_loss: 166.0132
# Epoch 17/50
# 60000/60000 [==============================] - 0s - loss: 165.9635 - val_loss: 165.7576
# Epoch 18/50
# 60000/60000 [==============================] - 0s - loss: 165.6417 - val_loss: 165.5325
# Epoch 19/50
# 60000/60000 [==============================] - 0s - loss: 165.3753 - val_loss: 165.1873
# Epoch 20/50
# 60000/60000 [==============================] - 0s - loss: 165.0957 - val_loss: 164.9617
# Epoch 21/50
# 60000/60000 [==============================] - 0s - loss: 164.8367 - val_loss: 164.7432
# Epoch 22/50
# 60000/60000 [==============================] - 0s - loss: 164.5811 - val_loss: 164.4707
# Epoch 23/50
# 60000/60000 [==============================] - 0s - loss: 164.3624 - val_loss: 164.3615
# Epoch 24/50
# 60000/60000 [==============================] - 0s - loss: 164.1443 - val_loss: 164.1116
# Epoch 25/50
# 60000/60000 [==============================] - 0s - loss: 163.9263 - val_loss: 163.9375
# Epoch 26/50
# 60000/60000 [==============================] - 0s - loss: 163.7458 - val_loss: 163.7622
# Epoch 27/50
# 60000/60000 [==============================] - 0s - loss: 163.5510 - val_loss: 163.6254
# Epoch 28/50
# 60000/60000 [==============================] - 0s - loss: 163.3697 - val_loss: 163.4381
# Epoch 29/50
# 60000/60000 [==============================] - 0s - loss: 163.1884 - val_loss: 163.2648
# Epoch 30/50
# 60000/60000 [==============================] - 0s - loss: 163.0490 - val_loss: 163.1032
# Epoch 31/50
# 60000/60000 [==============================] - 0s - loss: 162.8814 - val_loss: 163.0823
# Epoch 32/50
# 60000/60000 [==============================] - 0s - loss: 162.7428 - val_loss: 162.9770
# Epoch 33/50
# 60000/60000 [==============================] - 0s - loss: 162.5931 - val_loss: 162.8039
# Epoch 34/50
# 60000/60000 [==============================] - 0s - loss: 162.4624 - val_loss: 162.6379
# Epoch 35/50
# 60000/60000 [==============================] - 0s - loss: 162.3284 - val_loss: 162.5558
# Epoch 36/50
# 60000/60000 [==============================] - 0s - loss: 162.1915 - val_loss: 162.4428
# Epoch 37/50
# 60000/60000 [==============================] - 0s - loss: 162.0696 - val_loss: 162.3635
# Epoch 38/50
# 60000/60000 [==============================] - 0s - loss: 161.9379 - val_loss: 162.2713
# Epoch 39/50
# 60000/60000 [==============================] - 0s - loss: 161.8621 - val_loss: 162.1681
# Epoch 40/50
# 60000/60000 [==============================] - 0s - loss: 161.7504 - val_loss: 162.1091
# Epoch 41/50
# 60000/60000 [==============================] - 0s - loss: 161.6245 - val_loss: 162.0383
# Epoch 42/50
# 60000/60000 [==============================] - 0s - loss: 161.5194 - val_loss: 161.8869
# Epoch 43/50
# 60000/60000 [==============================] - 0s - loss: 161.4228 - val_loss: 161.8090
# Epoch 44/50
# 60000/60000 [==============================] - 0s - loss: 161.3143 - val_loss: 161.7508
# Epoch 45/50
# 60000/60000 [==============================] - 0s - loss: 161.2247 - val_loss: 161.7045
# Epoch 46/50
# 60000/60000 [==============================] - 0s - loss: 161.1381 - val_loss: 161.5861
# Epoch 47/50
# 60000/60000 [==============================] - 0s - loss: 161.0353 - val_loss: 161.4521
# Epoch 48/50
# 60000/60000 [==============================] - 0s - loss: 160.9382 - val_loss: 161.4385
# Epoch 49/50
# 60000/60000 [==============================] - 0s - loss: 160.8720 - val_loss: 161.3969
# Epoch 50/50
# 60000/60000 [==============================] - 0s - loss: 160.7809 - val_loss: 161.2568

# %% [markdown]
# # play with inference and the generative models separately

# %% [markdown]
# The encoder network can embed the 28x28 images in its latent space. It can even cluster them!

# %%
# encoder is the inference network
encoder=Model(X, z_mean)

# a 2d plot of 10 digit classes in latent space
x_test_encoded=encoder.predict(x_test, batch_size=batch_size)
plt.figure(figsize=(6,6))
plt.scatter(x_test_encoded[:,0], x_test_encoded[:,1], c=y_test)
plt.colorbar()
plt.show()

# %% [markdown]
# Now that we have learned the latent space distribution, we can sample from it can map it to an image through our decoder network. So we can now generate images. Pretty cool, eh !?

# %%
# since the generator treats z as an input we make the generator again w/ z as input
z_input=Input(shape=(latent_dim,))
_h_decoded=h_decoder(z_input)
_x_decoded=X_bar(_h_decoded)
generator= Model(z_input, _x_decoded)

z_sample=np.array([np.random.normal(0, 1, 2)])
x_decoded=generator.predict(z_sample)
sampled_im=x_decoded[0].reshape(digit_size,digit_size)
plt.imshow(sampled_im, cmap='Greys_r')
plt.show()

# %%
# 2d manifold of images
n=15
figure = np.zeros((digit_size*n, digit_size*n))

# the grid from quantiles of normal dist using the inverse of its cdf
grid_x=norm.ppf(np.linspace(0.05,0.95,n))
grid_y=norm.ppf(np.linspace(0.05,0.95,n))

for i, yi in enumerate(grid_x):
    for j,xi in enumerate(grid_y):
        z_sample=np.array([[xi,yi]])
        x_decoded=generator.predict(z_sample)
        digit=x_decoded[0].reshape(digit_size,digit_size)
        figure[i*digit_size:(i+1)*digit_size, 
              j*digit_size:(j+1)*digit_size]=digit
        
plt.figure(figsize=(10,10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
