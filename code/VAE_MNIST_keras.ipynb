# %% [markdown]
# # import stuff and set random seeds

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import objectives
from keras.datasets import mnist
from keras import backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: TITAN X (Pascal) (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)

# %% [markdown]
# # encoder/decode network size

# %%
batch_size=100
digit_size=28
original_dim=784
intermediate_dim=256
latent_dim=2

nb_epochs=50
epsilon_std=1.0

# %% [markdown]
# # encoder

# %%
X=Input(batch_shape=(batch_size,original_dim))
h=Dense(intermediate_dim, activation='relu')(X)
z_mean=Dense(latent_dim)(h)
z_log_var=Dense(latent_dim)(h)

# %% [markdown]
# # sampling from latent for decoder

# %%
def sampling(args):
    z_mean,z_log_var=args
    epsilon=K.random_normal(shape=(batch_size, latent_dim), mean=0., std=epsilon_std)
    return z_mean+K.exp(z_log_var/2)*epsilon

# a keras lambda layer computes arbitrary function on the output of a layer
# so z is effectively combining mean and variance layers through sampling func 
z= Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# %% [markdown]
# # decoder

# %%
h_decoder=Dense(intermediate_dim, activation='relu')
X_bar=Dense(original_dim,activation='sigmoid')

# we instantiate these layers separately so as to reuse them later
h_decoded = h_decoder(z)
X_decoded = X_bar(h_decoded)

# %% [markdown]
# # VAE loss

# %%
def vae_loss(x,x_bar):
    reconst_loss=original_dim*objectives.binary_crossentropy(x, x_bar)
    kl_loss=-0.5*K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return reconst_loss + kl_loss

# %% [markdown]
# # compile model and ready data for training

# %%
# build and compile model
vae=Model(X , X_decoded)
vae.compile(optimizer='adam', loss=vae_loss)

# load MNIST data for training
(x_train, y_train),(x_test, y_test)=mnist.load_data()

# normalize input and make them float32 to run on GPU
x_train=x_train.astype('float32')/ 255.
x_test=x_test.astype('float32')/255.

# convert 28x28 images into 784-vectors
x_train=x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test=x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %% [markdown]
# # train model based on the loss func we defined

# %%
# x_train is required for input and loss output as target
vae.fit(x_train,x_train, shuffle=True, nb_epoch=nb_epochs, batch_size=batch_size, validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 0s - loss: 200.6449 - val_loss: 173.4382
# Epoch 2/50
# 60000/60000 [==============================] - 0s - loss: 170.8674 - val_loss: 168.0028
# Epoch 3/50
# 60000/60000 [==============================] - 0s - loss: 166.5989 - val_loss: 165.1868
# Epoch 4/50
# 60000/60000 [==============================] - 0s - loss: 164.0337 - val_loss: 163.1323
# Epoch 5/50
# 60000/60000 [==============================] - 0s - loss: 162.1081 - val_loss: 161.5220
# Epoch 6/50
# 60000/60000 [==============================] - 0s - loss: 160.4914 - val_loss: 160.1124
# Epoch 7/50
# 60000/60000 [==============================] - 0s - loss: 159.1692 - val_loss: 159.1551
# Epoch 8/50
# 60000/60000 [==============================] - 0s - loss: 158.1139 - val_loss: 158.1947
# Epoch 9/50
# 60000/60000 [==============================] - 0s - loss: 157.2188 - val_loss: 157.3583
# Epoch 10/50
# 60000/60000 [==============================] - 0s - loss: 156.4889 - val_loss: 156.8600
# Epoch 11/50
# 60000/60000 [==============================] - 0s - loss: 155.8387 - val_loss: 156.2500
# Epoch 12/50
# 60000/60000 [==============================] - 0s - loss: 155.2355 - val_loss: 155.7939
# Epoch 13/50
# 60000/60000 [==============================] - 0s - loss: 154.7879 - val_loss: 155.5299
# Epoch 14/50
# 60000/60000 [==============================] - 0s - loss: 154.3226 - val_loss: 154.9652
# Epoch 15/50
# 60000/60000 [==============================] - 0s - loss: 153.9134 - val_loss: 154.7156
# Epoch 16/50
# 60000/60000 [==============================] - 0s - loss: 153.5694 - val_loss: 154.3401
# Epoch 17/50
# 60000/60000 [==============================] - 0s - loss: 153.2266 - val_loss: 154.0957
# Epoch 18/50
# 60000/60000 [==============================] - 0s - loss: 152.8726 - val_loss: 153.7865
# Epoch 19/50
# 60000/60000 [==============================] - 0s - loss: 152.5953 - val_loss: 153.6586
# Epoch 20/50
# 60000/60000 [==============================] - 0s - loss: 152.2934 - val_loss: 153.4580
# Epoch 21/50
# 60000/60000 [==============================] - 0s - loss: 152.0399 - val_loss: 153.3124
# Epoch 22/50
# 60000/60000 [==============================] - 0s - loss: 151.7988 - val_loss: 153.1975
# Epoch 23/50
# 60000/60000 [==============================] - 0s - loss: 151.5857 - val_loss: 152.8784
# Epoch 24/50
# 60000/60000 [==============================] - 0s - loss: 151.3374 - val_loss: 152.9478
# Epoch 25/50
# 60000/60000 [==============================] - 0s - loss: 151.0897 - val_loss: 152.6208
# Epoch 26/50
# 60000/60000 [==============================] - 0s - loss: 150.9156 - val_loss: 152.4815
# Epoch 27/50
# 60000/60000 [==============================] - 0s - loss: 150.7462 - val_loss: 152.6022
# Epoch 28/50
# 60000/60000 [==============================] - 0s - loss: 150.5570 - val_loss: 152.5236
# Epoch 29/50
# 60000/60000 [==============================] - 0s - loss: 150.3467 - val_loss: 152.4587
# Epoch 30/50
# 60000/60000 [==============================] - 0s - loss: 150.2131 - val_loss: 152.0490
# Epoch 31/50
# 60000/60000 [==============================] - 0s - loss: 150.0723 - val_loss: 151.9412
# Epoch 32/50
# 60000/60000 [==============================] - 0s - loss: 149.9003 - val_loss: 151.8992
# Epoch 33/50
# 60000/60000 [==============================] - 0s - loss: 149.7914 - val_loss: 151.8831
# Epoch 34/50
# 60000/60000 [==============================] - 0s - loss: 149.5980 - val_loss: 151.7552
# Epoch 35/50
# 60000/60000 [==============================] - 0s - loss: 149.4862 - val_loss: 151.5255
# Epoch 36/50
# 60000/60000 [==============================] - 0s - loss: 149.3531 - val_loss: 151.5205
# Epoch 37/50
# 60000/60000 [==============================] - 0s - loss: 149.2308 - val_loss: 151.5220
# Epoch 38/50
# 60000/60000 [==============================] - 0s - loss: 149.1395 - val_loss: 151.3095
# Epoch 39/50
# 60000/60000 [==============================] - 0s - loss: 148.9651 - val_loss: 151.0549
# Epoch 40/50
# 60000/60000 [==============================] - 0s - loss: 148.8276 - val_loss: 151.3528
# Epoch 41/50
# 60000/60000 [==============================] - 0s - loss: 148.7383 - val_loss: 151.3094
# Epoch 42/50
# 60000/60000 [==============================] - 0s - loss: 148.6237 - val_loss: 151.2814
# Epoch 43/50
# 60000/60000 [==============================] - 0s - loss: 148.5437 - val_loss: 151.4732
# Epoch 44/50
# 60000/60000 [==============================] - 0s - loss: 148.4435 - val_loss: 151.1872
# Epoch 45/50
# 60000/60000 [==============================] - 0s - loss: 148.3206 - val_loss: 151.2692
# Epoch 46/50
# 60000/60000 [==============================] - 0s - loss: 148.2553 - val_loss: 151.1699
# Epoch 47/50
# 60000/60000 [==============================] - 0s - loss: 148.1293 - val_loss: 151.1311
# Epoch 48/50
# 60000/60000 [==============================] - 0s - loss: 148.0296 - val_loss: 150.9162
# Epoch 49/50
# 60000/60000 [==============================] - 0s - loss: 147.8991 - val_loss: 151.0181
# Epoch 50/50
# 60000/60000 [==============================] - 0s - loss: 147.8520 - val_loss: 151.1519

# %% [markdown]
# # play with inference and the generative models separately

# %% [markdown]
# The encoder network can embed the 28x28 images in its latent space. It can even cluster them!

# %%
# encoder is the inference network
encoder=Model(X, z_mean)

# a 2d plot of 10 digit classes in latent space
x_test_encoded=encoder.predict(x_test, batch_size=batch_size)
plt.figure(figsize=(6,6))
plt.scatter(x_test_encoded[:,0], x_test_encoded[:,1], c=y_test)
plt.colorbar()
plt.show()

# %% [markdown]
# Now that we have learned the latent space distribution, we can sample from it can map it to an image through our decoder network. So we can now generate images. Pretty cool, eh !?

# %%
# since the generator treats z as an input we make the generator again w/ z as input
z_input=Input(shape=(latent_dim,))
_h_decoded=h_decoder(z_input)
_x_decoded=X_bar(_h_decoded)
generator= Model(z_input, _x_decoded)

z_sample=np.array([np.random.normal(0, 1, 2)])
x_decoded=generator.predict(z_sample)
sampled_im=x_decoded[0].reshape(digit_size,digit_size)
plt.imshow(sampled_im, cmap='Greys_r')
plt.show()

# %%
# 2d manifold of images
n=15
figure = np.zeros((digit_size*n, digit_size*n))

# the grid from quantiles of normal dist using the inverse of its cdf
grid_x=norm.ppf(np.linspace(0.05,0.95,n))
grid_y=norm.ppf(np.linspace(0.05,0.95,n))

for i, yi in enumerate(grid_x):
    for j,xi in enumerate(grid_y):
        z_sample=np.array([[xi,yi]])
        x_decoded=generator.predict(z_sample)
        digit=x_decoded[0].reshape(digit_size,digit_size)
        figure[i*digit_size:(i+1)*digit_size, 
              j*digit_size:(j+1)*digit_size]=digit
        
plt.figure(figsize=(10,10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
